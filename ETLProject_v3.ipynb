# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from pandas import DataFrame
import psycopg2

# %%
# Store insurance csv into a dataframe
csv_file = "../Resources/insurance.csv"
insurance_data_df = pd.read_csv(csv_file)
insurance_data_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Value count to identify unique values - Gender count
count = insurance_data_df["sex"].value_counts()
count
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
# Create a filtered dataframe from specific columns - multiples for insurance based on Gender and Charges
insurance_data_df = insurance_data_df[['sex', 'age', 'bmi', 'charges']].copy()
insurance_data_df.head()
# Out:
#       sex  age     bmi      charges
# 0  female   19  27.900  16884.92400
# 1    male   18  33.770   1725.55230
# 2    male   28  33.000   4449.46200
# 3    male   33  22.705  21984.47061
# 4    male   32  28.880   3866.85520

# %%
# Statistical data conversion for insurance data source
insurance_data_df.describe()
# Out:
#                age          bmi       charges
# count  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397  13270.422265
# std      14.049960     6.098187  12110.011237
# min      18.000000    15.960000   1121.873900
# 25%      27.000000    26.296250   4740.287150
# 50%      39.000000    30.400000   9382.033000
# 75%      51.000000    34.693750  16639.912515
# max      64.000000    53.130000  63770.428010

# %%
# Store csv into a dataframe
csv_file = "../Resources/hospital.csv"
hospital_data_df = pd.read_csv(csv_file)
hospital_data_df.head()
# Out:
#    AGE  FEMALE  LOS  RACE  TOTCHG  APRDRG
# 0   17       1    2   1.0    2660     560
# 1   17       0    2   1.0    1689     753
# 2   17       1    7   1.0   20060     930
# 3   17       1    1   1.0     736     758
# 4   17       1    1   1.0    1194     754

# %%
# Display of the hospital dataset
hospital_data_df.head(10)
# Out:
#    AGE  FEMALE  LOS  RACE  TOTCHG  APRDRG
# 0   17       1    2   1.0    2660     560
# 1   17       0    2   1.0    1689     753
# 2   17       1    7   1.0   20060     930
# 3   17       1    1   1.0     736     758
# 4   17       1    1   1.0    1194     754
# 5   17       0    0   1.0    3305     347
# 6   17       1    4   1.0    2205     754
# 7   16       1    2   1.0    1167     754
# 8   16       1    1   1.0     532     753
# 9   17       1    2   1.0    1363     758

# %%
# Statistical view of the hospital dataset
hospital_data_df.describe().T
# Out:
#         count         mean          std    min      25%     50%      75%  \
# AGE     500.0     5.086000     6.949474    0.0     0.00     0.0    13.00
# FEMALE  500.0     0.512000     0.500357    0.0     0.00     1.0     1.00
# LOS     500.0     2.828000     3.363487    0.0     2.00     2.0     3.00
# RACE    499.0     1.078156     0.514746    1.0     1.00     1.0     1.00
# TOTCHG  500.0  2774.388000  3888.407367  532.0  1216.25  1536.5  2530.25
# APRDRG  500.0   616.360000   178.316044   21.0   640.00   640.0   751.00
#
#             max
# AGE        17.0
# FEMALE      1.0
# LOS        41.0
# RACE        6.0
# TOTCHG  48388.0
# APRDRG    952.0

# %%
# Create database connection
joining_string = "admin1:12345@localhost:5432/ETLProject"
engine = create_engine(f'postgresql://{joining_string}')

# %%
# Confirm Tables
engine.table_names()
# Out:
# ['insurance_data', 'hospital_data']

# %%
insurance_data_df.to_sql(name="insurance_data", con=engine, if_exists='append', index=False)

# %%
hospital_data_df.to_sql(name="hospital_data", con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM insurance_data', con=engine).head(10)
# Out:
#       sex  age     bmi      charges
# 0  female   19  27.900  16884.92400
# 1    male   18  33.770   1725.55230
# 2    male   28  33.000   4449.46200
# 3    male   33  22.705  21984.47061
# 4    male   32  28.880   3866.85520
# 5  female   31  25.740   3756.62160
# 6  female   46  33.440   8240.58960
# 7  female   37  27.740   7281.50560
# 8    male   37  29.830   6406.41070
# 9  female   60  25.840  28923.13692

# %%
pd.read_sql_query('SELECT * FROM hospital_data', con=engine).head(10)
# Out:
#    AGE  FEMALE  LOS  RACE  TOTCHG  APRDRG
# 0   17       1    2   1.0    2660     560
# 1   17       0    2   1.0    1689     753
# 2   17       1    7   1.0   20060     930
# 3   17       1    1   1.0     736     758
# 4   17       1    1   1.0    1194     754
# 5   17       0    0   1.0    3305     347
# 6   17       1    4   1.0    2205     754
# 7   16       1    2   1.0    1167     754
# 8   16       1    1   1.0     532     753
# 9   17       1    2   1.0    1363     758

# %%
# Create bins in which to place values based upon age
bins = [-1,18, 24, 34, 44, 54, 65]
# Create labels for these bins
group_labels = ['0 to 17','18 to 24', '25 to 34', '35 to 44', '45 to 54', '55 to 64']

# %%
# Slice the data and place it into bins
pd.cut(hospital_data_df["AGE"], bins, labels=group_labels)
# Out:
# 0      0 to 17
# 1      0 to 17
# 2      0 to 17
# 3      0 to 17
# 4      0 to 17
#         ...
# 495    0 to 17
# 496    0 to 17
# 497    0 to 17
# 498    0 to 17
# 499    0 to 17
# Name: AGE, Length: 500, dtype: category
# Categories (6, object): [0 to 17 < 18 to 24 < 25 to 34 < 35 to 44 < 45 to 54 < 55 to 64]

# %%
print(insurance_data_df['age'].mean,())
print(hospital_data_df['AGE'].mean())
# Out:
# <bound method Series.mean of 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64> ()
# 5.086

# %%
print(insurance_data_df['charges'].mean,())
print(hospital_data_df['TOTCHG'].mean())
# Out:
# <bound method Series.mean of 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64> ()
# 2774.388

# %%
insurance_data_df.groupby(by='age')['charges'].mean()
# Out:
# age
# 18     7086.217556
# 19     9747.909335
# 20    10159.697736
# 21     4730.464330
# 22    10012.932802
# 23    12419.820040
# 24    10648.015962
# 25     9838.365311
# 26     6133.825309
# 27    12184.701721
# 28     9069.187564
# 29    10430.158727
# 30    12719.110358
# 31    10196.980573
# 32     9220.300291
# 33    12351.532987
# 34    11613.528121
# 35    11307.182031
# 36    12204.476138
# 37    18019.911877
# 38     8102.733674
# 39    11778.242945
# 40    11772.251310
# 41     9653.745650
# 42    13061.038669
# 43    19267.278653
# 44    15859.396587
# 45    14830.199856
# 46    14342.590639
# 47    17653.999593
# 48    14632.500445
# 49    12696.006264
# 50    15663.003301
# 51    15682.255867
# 52    18256.269719
# 53    16020.930755
# 54    18758.546475
# 55    16164.545488
# 56    15025.515837
# 57    16447.185250
# 58    13878.928112
# 59    18895.869532
# 60    21979.418507
# 61    22024.457609
# 62    19163.856573
# 63    19884.998461
# 64    23275.530837
# Name: charges, dtype: float64

# %%
hospital_data_df.groupby(by='LOS')['TOTCHG'].mean()
# Out:
# LOS
# 0      1606.200000
# 1      1907.721519
# 2      1707.986607
# 3      2537.367347
# 4      3415.526316
# 5      5372.500000
# 6      8370.500000
# 7     12307.272727
# 8      5014.000000
# 9     16520.000000
# 10     5615.000000
# 12    10969.500000
# 15     8631.000000
# 17    12042.000000
# 18    11167.000000
# 23    13112.000000
# 24    13040.000000
# 39    26356.000000
# 41    29188.000000
# Name: TOTCHG, dtype: float64

# %%
# Descriptive statistics on the Hospital dataframe
hospital_data_df.groupby(by='AGE')['TOTCHG'].describe()
# Out:
#      count          mean          std      min       25%      50%       75%  \
# AGE
# 0    307.0   2208.853420  2784.135079    550.0   1263.00   1483.0   2015.50
# 1     10.0   3774.400000  2932.268148   1409.0   1666.00   2524.5   4751.75
# 2      1.0   7298.000000          NaN   7298.0   7298.00   7298.0   7298.00
# 3      3.0  10183.333333  3516.461337   8084.0   8153.50   8223.0  11233.00
# 4      2.0   7996.000000  1745.139536   6762.0   7379.00   7996.0   8613.00
# 5      2.0   9253.500000  1881.611145   7923.0   8588.25   9253.5   9918.75
# 6      2.0   8964.000000   800.444876   8398.0   8681.00   8964.0   9247.00
# 7      3.0   3362.333333  2742.908371   1132.0   1831.00   2530.0   4477.50
# 8      2.0   2370.500000  1721.805012   1153.0   1761.75   2370.5   2979.25
# 9      2.0  10573.500000    16.263456  10562.0  10567.75  10573.5  10579.25
# 10     4.0   6117.250000  7648.276729   1160.0   2435.00   2892.5   6574.75
# 11     8.0   1781.250000  1311.825527    629.0    992.00   1231.5   2104.00
# 12    15.0   3660.800000  4885.054133    622.0   1225.00   1647.0   2910.00
# 13    18.0   1729.722222  1321.940633    548.0    950.75   1242.0   2219.75
# 14    25.0   2585.720000  2655.196187    625.0    763.00   1463.0   3045.00
# 15    29.0   3853.344828  5175.789396    607.0    783.00   1956.0   3102.00
# 16    29.0   2384.448276  2391.920516    532.0   1163.00   1385.0   2543.00
# 17    38.0   4599.394737  8274.896124    610.0   1274.50   2211.0   3312.50
#
#          max
# AGE
# 0    29188.0
# 1     9606.0
# 2     7298.0
# 3    14243.0
# 4     9230.0
# 5    10584.0
# 6     9530.0
# 7     6425.0
# 8     3588.0
# 9    10585.0
# 10   17524.0
# 11    3908.0
# 12   17434.0
# 13    5615.0
# 14   10756.0
# 15   20195.0
# 16   10002.0
# 17   48388.0

# %%
# Descriptive statistics on the Insurance dataframe
insurance_data_df.groupby(by='age')['charges'].describe()
# Out:
#      count          mean           std          min           25%  \
# age
# 64    22.0  23275.530837  13029.841607  13822.80300  14398.651450
#
#               50%           75%          max
# age
# 18    2198.189850  11272.331390  38792.68560
# 19    2135.891875  17148.980075  39722.74620
# 20    2459.720100  17085.267600  38344.56600
# 21    2254.423600   3205.349713  26018.95052
# 22    2641.155700   4078.134675  44501.39820
# 23    3594.538000  19145.024148  40904.19950
# 24    3045.137650  17508.424985  38126.24650
# 25    3750.148925  16333.214445  42112.23560
# 26    3388.882175   3983.464100  36085.21900
# 27    4544.324475  18262.557125  39611.75770
# 28    4344.951450   5387.969638  51194.55914
# 29    4906.409650  16398.239750  44585.45587
# 30    4837.582300  18864.523685  40932.42950
# 31    4738.268200   5769.127200  58571.07448
# 32    4672.016100   6282.957025  37607.52770
# 33    6210.083300  15683.447812  55135.40209
# 34    5490.091700  13703.235488  43943.87610
# 35    5836.520400  19361.998800  39983.42595
# 36    5478.036800   7243.813600  43753.33705
# 37    6985.506950  37270.151200  46113.51100
# 38    6455.862650   6933.242250  41949.24410
# 39    7512.267000  19023.260000  40103.89000
# 40    7077.189400  12040.553015  40003.33225
# 41    6875.961000   7560.464200  40273.64550
# 42    7443.643050  19740.143950  43896.37630
# 43   18767.737700  22179.710000  45863.20500
# 44    8023.135450  16196.009635  48885.13561
# 45    8603.823400   9788.865900  62592.87309
# 46    8825.086000   9500.573050  46151.12450
# 47    9715.841000  24535.698550  44202.65360
# 48    9447.382400  21223.675800  45702.02235
# 49    9681.120250  10530.410600  39727.61400
# 50   10107.220600  19749.383380  42856.83800
# 51    9875.680400  11436.738150  47462.89400
# 52   11396.900200  24667.419000  60021.39897
# 53   11157.174000  20646.202745  46661.44240
# 54   11816.449500  24702.933133  63770.42801
# 55   11880.231025  12906.949488  44423.80300
# 56   11658.247100  12573.420100  43921.18370
# 57   11893.878225  14101.812875  48675.51770
# 58   11931.125250  12231.613600  47496.49445
# 59   12928.791100  21797.000400  48970.24760
# 60   13204.285650  29591.566240  52590.82939
# 61   13635.637900  29005.012100  48517.56315
# 62   13844.797200  21306.589040  46718.16325
# 63   14349.854400  15362.628875  48824.45000
# 64   15528.758375  28757.715888  49577.66240

# %%
# Data sources pulled from Kaggle. The two datasets used are 'Medical Costs Personal Datasets' & 'Hospital Costs'
# The datasets provide information from the insurance perspective and the hospital perspective, which vary based on a few key components.
# There are several variables associated with charges. The prevalent aspects effecting charges are 'Region', 'Gender', 'LOS(Length of stay)', 'Age', 'Level of Service'
# which is also dictated by the APRDRG (Coding formulary).

# %%
# The datasets were scrubbed to provide various scenarios of the information contained in the datasets (e.g. Insurance & Hospital) 
# Both datasets consisted of the age group from birth - 64; as we didn't include the Medicare aged population (those 65+) as the charges are 
# based on the Medicare Fee Schedule and highly regulated (Federal Government). 
# Thus, our final table used reflects the statistical data relevant to both age/charges in the Insurance and Hospital categories.

# %%
# ETL Project partners: Kruti Gandhi and Louis Starr.
